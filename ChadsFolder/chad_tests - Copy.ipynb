# %%
# Import the modules
import pandas as pd
from pathlib import Path

# %%
# Read in the CSV file as a Pandas DataFrame
titles_df = pd.read_csv(
    Path("Data/titles.csv")
)


movies_df = pd.read_csv(
    Path("Data/movies.csv")
)

# %%
if movies_df['title'].str.contains('Harry Potter').any():
    print ('yes')
# Out:
# yes

# %%
titles_df['imdb_score'].value_counts()
# Out:
# imdb_score
# 6.5    206
# 7.1    200
# 7.4    197
# 6.7    196
# 6.8    191
#       ...
# 9.2      1
# 1.7      1
# 9.6      1
# 2.4      1
# 1.6      1
# Name: count, Length: 80, dtype: int64

# %%
movies_df.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_df['title'] = movies_df['title'].str[:-7]

# %%
movies_df['title']
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 62418                             We
# 62419             Window of the Soul
# 62420                      Bad Poems
# 62421                   A Girl Thing
# 62422        Women of Devil's Island
# Name: title, Length: 62423, dtype: object

# %%
merged_df = pd.merge(movies_df, titles_df, on='title')

# %%
merged_df.head()
# Out:
#    movieId       title        genres_x         id   type  \
# 0        7     Sabrina  Comedy|Romance   tm371619  MOVIE
# 1      915     Sabrina  Comedy|Romance   tm371619  MOVIE
# 2   196339     Sabrina          Horror   tm371619  MOVIE
# 3       28  Persuasion   Drama|Romance  tm1170388  MOVIE
# 4    74508  Persuasion   Drama|Romance  tm1170388  MOVIE
#
#                                          description  release_year  \
# 0  Maira lives happily with Aiden, a doll maker a...          2018
# 1  Maira lives happily with Aiden, a doll maker a...          2018
# 2  Maira lives happily with Aiden, a doll maker a...          2018
# 3  Living with her snobby family on the brink of ...          2022
# 4  Living with her snobby family on the brink of ...          2022
#
#   age_certification  runtime                        genres_y  \
# 0               NaN       98          ['horror', 'thriller']
# 1               NaN       98          ['horror', 'thriller']
# 2               NaN       98          ['horror', 'thriller']
# 3                PG      107  ['romance', 'drama', 'comedy']
# 4                PG      107  ['romance', 'drama', 'comedy']
#
#   production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0   ['ID', 'MY', 'SG']      NaN   tt7981492         4.1      1757.0
# 1   ['ID', 'MY', 'SG']      NaN   tt7981492         4.1      1757.0
# 2   ['ID', 'MY', 'SG']      NaN   tt7981492         4.1      1757.0
# 3         ['US', 'GB']      NaN  tt13456318         NaN         NaN
# 4         ['US', 'GB']      NaN  tt13456318         NaN         NaN
#
#    tmdb_popularity  tmdb_score
# 0           19.396         5.3
# 1           19.396         5.3
# 2           19.396         5.3
# 3          127.205         6.0
# 4          127.205         6.0

# %%
merged_df.to_csv("Data/merged_movies_w_description.csv", index=False)

# %%
# Split title on (
movies_df[['titles', 'year']] = movies_df['title'].str.split('(', n=1, expand=True)

# Remove whitespace at end of title
movies_df['titles'] = movies_df['titles'].str.strip()

# Strip ) off of year
movies_df['year'] = movies_df['year'].str.rstrip(')')

# %%
movies_df = movies_df[movies_df['genres'].notna()]

movies_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
#                             titles  year
# 0                        Toy Story  1995
# 1                          Jumanji  1995
# 2                 Grumpier Old Men  1995
# 3                Waiting to Exhale  1995
# 4      Father of the Bride Part II  1995
# ...                            ...   ...
# 62418                           We  2018
# 62419           Window of the Soul  2001
# 62420                    Bad Poems  2018
# 62421                 A Girl Thing  2001
# 62422      Women of Devil's Island  1962
#
# [62423 rows x 5 columns]

# %%
movie_id = []

for i, movie in movies_df.iterrows():
    try:
        year = int(movie['year'])
    except:
        print('ValueError')

    if year < 2010:
        movie_id.append(movie['movieId'])
# Out:
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError
# ValueError

# %%
len(movie_id)
# Out:
# 41459

# %%
# Drop rows that have same movieID as listed in movie_id
movies_reduced = movies_df[~movies_df['movieId'].isin(movie_id)]

movies_reduced.count()
# Out:
# movieId    20964
# title      20964
# genres     20964
# titles     20964
# year       20744
# dtype: int64

# %%
rating_df.count()
# Out:
# userId       25000095
# movieId      25000095
# rating       25000095
# timestamp    25000095
# dtype: int64

# %%
rating_reduced = rating_df[~rating_df['movieId'].isin(movie_id)]

rating_reduced.count()
# Out:
# userId       2673702
# movieId      2673702
# rating       2673702
# timestamp    2673702
# dtype: int64
